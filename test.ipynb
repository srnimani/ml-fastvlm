# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
model_dir = "checkpoints/llava-fastvithd_0.5b_stage2" # checkpoints/llava-fastvithd_0.5b_stage3_llm.fp16
#model_dir = "ckpoints/llava-fastvithd_0.5b_stage3_llm.fp16"
# !ls -l {model_dir}
# Out:
# total 3005776
# -rw-r--r--  1 srnimani  staff          80 Apr 16 07:12 added_tokens.json
# -rw-r--r--  1 srnimani  staff        1274 Apr 16 07:12 config.json
# -rw-r--r--  1 srnimani  staff     1670344 Apr 16 07:12 merges.txt
# -rw-r--r--  1 srnimani  staff  1517793184 Apr 16 07:12 model.safetensors
# -rw-r--r--  1 srnimani  staff         367 Apr 16 07:12 special_tokens_map.json
# -rw-r--r--  1 srnimani  staff        1325 Apr 16 07:12 tokenizer_config.json
# -rw-r--r--  1 srnimani  staff    16078066 Apr 16 07:12 trainer_state.json
# -rw-r--r--  1 srnimani  staff        6584 Apr 16 07:12 training_args.bin
# -rw-r--r--  1 srnimani  staff     3383407 Apr 16 07:12 vocab.json

# %%
# %%time
# !python predict.py --model-path {model_dir}\
                  --image-file images/IMG_5997.jpg \
                  --prompt "Describe the image."
# Out:
# The image depicts a rugged coastal landscape with a prominent stone fortification. The fortification is built on a steep cliff, characterized by jagged rock formations and a series of stone walls. The walls are constructed from large, irregularly shaped stones, and the fortification appears to be ancient, with some parts of the structure showing signs of wear and erosion.
#
# The fortification is situated on a rocky outcrop that overlooks a vast body of water, likely the sea, given the presence of boats and the distant coastline. The sea is calm, with a few small boats visible in the distance. The coastline is densely populated with buildings, suggesting a coastal city or town. The buildings are closely packed together, with a mix of architectural styles, and they are interspersed with patches of greenery, indicating a blend of natural and urban environments.
#
# ...

# %%
plt.imshow(cv2.cvtColor(cv2.imread("images/IMG_5997.jpg"), cv2.COLOR_BGR2RGB))
# !python predict.py --model-path {model_dir}\
                  --image-file images/IMG_5997.jpg \
                  --prompt "Describe the image."
# Out:
# The image depicts a historical fortification situated atop a rugged cliff. The fortification is constructed from stone and features a series of walls and towers. The structure appears to be in a state of disrepair, with some parts of the walls and towers showing signs of decay and erosion. The cliff is steep and rocky, with patches of vegetation sprouting from the surface, indicating a natural, possibly coastal environment.
#
# In the background, the sea is visible, with a clear view of the horizon. The sea extends to the horizon, meeting the sky at a distant point. The sky is partly cloudy, with patches of blue sky visible between the clouds, suggesting a partly cloudy day.
#
# ...

# %%
plt.imshow(cv2.cvtColor(cv2.imread("images/IMG_6011.jpg"), cv2.COLOR_BGR2RGB))
# !python predict.py --model-path {model_dir}\
                  --image-file images/IMG_6011.jpg \
                  --prompt "Describe the image."
# Out:
# The image depicts a natural rock formation that forms a natural archway. The archway is composed of rugged, uneven rock formations with various shades of orange and brown, indicative of a desert or arid environment. The rock is layered, with some areas showing smoother surfaces while others are more jagged and rough. The archway is centrally positioned, creating a focal point that draws the viewer's attention.
#
# Through the archway, a serene body of water is visible. The water appears calm, with gentle ripples suggesting a light breeze or a slow current. The color of the water is a pale blue, which contrasts with the warm tones of the rock. The water extends from the archway to the horizon, indicating that the arch is quite wide.
#
# ...

# %%
plt.imshow(cv2.cvtColor(cv2.imread("images/IMG_6017.jpg"), cv2.COLOR_BGR2RGB))
# !python predict.py --model-path {model_dir} \
                  --image-file images/IMG_6017.jpg \
                  --prompt "Describe the image."
# Out:
# The image depicts a breathtaking coastal landscape. The foreground is dominated by a rocky cliff, which is covered with dry, golden grasses and sparse shrubs. The cliff's rugged texture contrasts with the smooth, deep blue waters of the sea below. The sea extends to the horizon, its surface calm and undisturbed, reflecting the light of the sky.
#
# In the middle ground, there is a small, isolated island with a rocky coastline. The island appears to be uninhabited, with no visible structures or signs of human activity. The island is surrounded by the sea, and its position relative to the cliff suggests it is a significant feature in the landscape.
#
# Further in the background, a large body of water, likely the sea, stretches out towards the horizon. This body of water is relatively calm, with only minor ripples visible on its surface. On the horizon, there is a faint outline of land, possibly a distant coastline or a small island, partially obscured by the clouds.
#
# ...

# %%
plt.imshow(cv2.cvtColor(cv2.imread("images/IMG_6039.jpg"), cv2.COLOR_BGR2RGB))
# !python predict.py --model-path {model_dir}\
                  --image-file images/IMG_6039.jpg \
                  --prompt "Describe the image."
# Out:
# The image depicts a historical site featuring ancient ruins, likely of a significant archaeological site. The central focus is an imposing stone archway, constructed from large, irregularly shaped stones. The archway is adorned with intricate carvings, including a prominent relief of a human figure, possibly a deity or a significant historical figure, positioned centrally within the arch. The figure appears to be holding a staff or scepter, suggesting a symbolic or religious significance.
#
# The archway is framed by two sturdy stone walls, each constructed from similar large stones. The walls are uneven and show signs of weathering, indicating their age and exposure to the elements over time. The archway leads to a pathway that appears to be made of wood or a similar material, providing a pathway for visitors to walk through.
#
# ...
